# %%
import glob
import ipynbname
import json
import os
import random
import sys
from pathlib import Path

import numpy as np
import pandas as pd
from scipy import ndimage, stats
from scipy.interpolate import CubicSpline

import tensorflow as tf
import tensorflow.keras.backend as K
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Layer, Add, Activation

import matplotlib.animation as animation
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from matplotlib.colors import ListedColormap

import pydicom

from losses import *
from MultiFlowSeg import *
from utils import *

import volumentations as V
# Out:
# 2024-11-04 11:18:46.532813: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image_size = 128
frames = 32
data_path = f'../data/clean_{image_size}_{frames}'
with open('patients5.json', 'r') as json_file:
    patients = json.load(json_file)

train_patients, val_patients, test_patients = patients['train'],patients['val'],patients['test']

patients = train_patients +  val_patients + test_patients 
all_patients =sorted(np.unique(['_'.join(pat.split('_')[:2]).split('/')[-1].replace('.npy','') for pat in glob.glob(f'{data_path}/*')]))
len(train_patients), len(val_patients), len(test_patients)

# %%
venc_df = pd.read_csv('venc.csv')
class CustomDataGen():    
    def __init__(self, 
                 patients,
                 cohort, 
                 vessel = ''
                ):
        self.patients = patients
        self.cohort = cohort
        self.vessel = vessel
        
    def data_generator(self):
        vessel_indices = list(vessels_dict.keys())[1:] if self.cohort != 'test' else [self.vessel]
        num_vessels = len(vessels_dict) 
        for patient in self.patients:
            for vessel in vessel_indices: 
                vessel_index = vessels_dict[vessel]
                mag_image, phase_image, mask = np.load(f'{data_path}/{patient}_{vessel}.npy', allow_pickle = True)
                mag_image[mag_image<1e-10] = 0                
                max_val = np.max(phase_image)

                venc = venc_df.loc[(venc_df['patient'] == patient) & (venc_df['vessel'] == vessel)].venc.values[0]
                angles = phase2angle(phase_image, venc)
                mag_image = (mag_image - np.min(mag_image))/(np.max(mag_image))
                mag_image[mag_image>=1] = 1

                mask[mask > 0.5] = 1
                mask[mask <= 0.5] = 0
                mask = mask.astype('uint8')
                
                if self.cohort == 'train':
                    phase_image = phase_image.astype('float32')/max_val
                    mask_phase = np.stack([mask, phase_image], -1)
                    
                    aug = get_volumentation(image_size, frames, vessel)
                    aug_data = aug(image = mag_image, mask = mask_phase)
                    mag_image, mask_phase = aug_data['image'], aug_data['mask']
                    mask, phase_image = mask_phase[...,0], mask_phase[...,1]
                    angles = phase2angle(phase_image, venc)
                    
                mag_image = skimage.exposure.equalize_adapthist(mag_image)
                complex_image = create_complex_image(mag_image, angles)
                real_image, imaginary_image = complex_image[...,0],complex_image[...,1]
                if self.cohort == 'train' and random.random()<0.5:
                    imaginary_image = -imaginary_image
                mag_image = normalise(mag_image)        
                imaginary_image = normalise(imaginary_image)        
                phase_image = normalise(phase_image)        

                X = np.stack([mag_image, imaginary_image], -1)
                one_hot_mask = np.zeros((image_size, image_size, frames, num_vessels), dtype='uint8')
                bkg = (mask == 0).astype('uint8')  # Background is where mask is not 1
                one_hot_mask[..., 0] = bkg
                one_hot_mask[..., vessel_index] = mask
                y = one_hot_mask
                
                cgm_input = tf.one_hot(vessel_index, len(vessels_dict))
                if self.cohort == 'test':
                    description = series_description_df.loc[patient,vessel].seriesdescription
                    description = description.replace('_',' ').replace('.',' ').replace('x','').replace('  ',' ').split(' ')
                    labels = []
                    for token in description:
                        strings = is_token_in_dictionary(token, data_dictionary.keys()) + is_token_a_substring_in_dictionary(data_dictionary.keys(), description)
                        if len(strings)>0:
                            for string in strings:
                                labels.append(data_dictionary[string])
                        print(labels, strings)
                    if len(labels) == 0:
                        label = 0
                    else:
                        label = pd.Series(labels).value_counts().index[0]
                        
                    one_hot = vessels_dict[label] if label in vessels_dict.keys() else 0
                    print(description, one_hot, label)
                    one_hot_input = tf.one_hot(one_hot, len(vessels_dict))#[np.newaxis] 
                else:
                    if self.cohort == 'train' and random.random() < 0.05:
                        one_hot_input = tf.one_hot(random.randint(0,5), len(vessels_dict))
                    else:
                        one_hot_input = cgm_input
                yield {'image_input':X.astype('float32'), 'cgm_input': cgm_input,'one_hot_input':one_hot_input,'mask_input': y.astype('uint8')},  y

    def get_gen(self):
        return self.data_generator()

# %%
input_channel = 2
out_channels =len(vessels_dict)

input_shape = [image_size,image_size, frames, input_channel]
output_shape = [image_size,image_size, frames, out_channels]


train_gen = CustomDataGen(train_patients, 'train').get_gen
val_gen   = CustomDataGen(val_patients, 'val').get_gen

output_signature = (
    {'image_input': tf.TensorSpec(shape=input_shape, dtype=tf.float32), 
     'cgm_input': tf.TensorSpec(shape=[6,], dtype=tf.uint8),
     'one_hot_input': tf.TensorSpec(shape=[6,], dtype=tf.uint8),
    'mask_input':    tf.TensorSpec(shape=output_shape, dtype=tf.uint8),
    },
    tf.TensorSpec(shape=output_shape, dtype=tf.uint8))

train_ds = tf.data.Dataset.from_generator(train_gen, output_signature = output_signature)

val_ds = tf.data.Dataset.from_generator(val_gen, output_signature = output_signature)

BATCH_SIZE = 8
train_ds = train_ds.shuffle(int(len(train_patients)/8), seed = 42, reshuffle_each_iteration=True).batch(BATCH_SIZE).prefetch(-1)
val_ds = val_ds.batch(BATCH_SIZE).prefetch(-1)

# %%
if continue_training:
    model =  tf.keras.models.load_model(f'models/{model_name}.h5', compile = False)
    print('model loaded')
else:
    model = build_multiflowseg()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  image_input (InputLayer)    [(None, 128, 128, 32, 2)]    0         []
#
#  conv3d (Conv3D)             (None, 128, 128, 32, 16)     880       ['image_input[0][0]']
#
#  batch_normalization (Batch  (None, 128, 128, 32, 16)     64        ['conv3d[0][0]']
#  Normalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 128, 128, 32, 16)     0         ['batch_normalization[0][0]']
#
#  conv3d_1 (Conv3D)           (None, 128, 128, 32, 16)     6928      ['leaky_re_lu[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128, 128, 32, 16)     64        ['conv3d_1[0][0]']
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 128, 128, 32, 16)     0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv3d_2 (Conv3D)           (None, 128, 128, 32, 16)     6928      ['leaky_re_lu_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 128, 128, 32, 16)     64        ['conv3d_2[0][0]']
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 128, 128, 32, 16)     0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  encoding_1_maxpool (MaxPoo  (None, 64, 64, 32, 16)       0         ['leaky_re_lu_2[0][0]']
#  ling3D)
#
#  conv3d_3 (Conv3D)           (None, 64, 64, 32, 32)       13856     ['encoding_1_maxpool[0][0]']
#
#  batch_normalization_3 (Bat  (None, 64, 64, 32, 32)       128       ['conv3d_3[0][0]']
#  chNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 64, 64, 32, 32)       0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv3d_4 (Conv3D)           (None, 64, 64, 32, 32)       27680     ['leaky_re_lu_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64, 64, 32, 32)       128       ['conv3d_4[0][0]']
#  chNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 64, 64, 32, 32)       0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv3d_5 (Conv3D)           (None, 64, 64, 32, 32)       27680     ['leaky_re_lu_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 64, 64, 32, 32)       128       ['conv3d_5[0][0]']
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 64, 64, 32, 32)       0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  encoding_2_maxpool (MaxPoo  (None, 32, 32, 32, 32)       0         ['leaky_re_lu_5[0][0]']
#  ling3D)
#
#  conv3d_6 (Conv3D)           (None, 32, 32, 32, 64)       55360     ['encoding_2_maxpool[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 32, 64)       256       ['conv3d_6[0][0]']
#  chNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 32, 32, 32, 64)       0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv3d_7 (Conv3D)           (None, 32, 32, 32, 64)       110656    ['leaky_re_lu_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 32, 64)       256       ['conv3d_7[0][0]']
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 32, 32, 64)       0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv3d_8 (Conv3D)           (None, 32, 32, 32, 64)       110656    ['leaky_re_lu_7[0][0]']
#
#  batch_normalization_8 (Bat  (None, 32, 32, 32, 64)       256       ['conv3d_8[0][0]']
#  chNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 32, 32, 32, 64)       0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  encoding_3_maxpool (MaxPoo  (None, 16, 16, 32, 64)       0         ['leaky_re_lu_8[0][0]']
#  ling3D)
#
#  conv3d_9 (Conv3D)           (None, 16, 16, 32, 128)      221312    ['encoding_3_maxpool[0][0]']
#
#  batch_normalization_9 (Bat  (None, 16, 16, 32, 128)      512       ['conv3d_9[0][0]']
#  chNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 16, 16, 32, 128)      0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv3d_10 (Conv3D)          (None, 16, 16, 32, 128)      442496    ['leaky_re_lu_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 32, 128)      512       ['conv3d_10[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 16, 16, 32, 128)      0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv3d_11 (Conv3D)          (None, 16, 16, 32, 128)      442496    ['leaky_re_lu_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 16, 32, 128)      512       ['conv3d_11[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 16, 16, 32, 128)      0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  encoding_4_maxpool (MaxPoo  (None, 8, 8, 32, 128)        0         ['leaky_re_lu_11[0][0]']
#  ling3D)
#
#  conv3d_12 (Conv3D)          (None, 8, 8, 32, 255)        881535    ['encoding_4_maxpool[0][0]']
#
#  batch_normalization_12 (Ba  (None, 8, 8, 32, 255)        1020      ['conv3d_12[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 8, 8, 32, 255)        0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv3d_13 (Conv3D)          (None, 8, 8, 32, 255)        1755930   ['leaky_re_lu_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 8, 8, 32, 255)        1020      ['conv3d_13[0][0]']
#  tchNormalization)
#
#  one_hot_input (InputLayer)  [(None, 6)]                  0         []
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 8, 8, 32, 255)        0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  dense (Dense)               (None, 16)                   112       ['one_hot_input[0][0]']
#
#  conv3d_14 (Conv3D)          (None, 8, 8, 32, 255)        1755930   ['leaky_re_lu_13[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   1088      ['dense[0][0]']
#
#  batch_normalization_14 (Ba  (None, 8, 8, 32, 255)        1020      ['conv3d_14[0][0]']
#  tchNormalization)
#
#  tf.reshape (TFOpLambda)     (None, 8, 8, 1, 1)           0         ['dense_1[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 8, 8, 32, 255)        0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  tf.tile (TFOpLambda)        (None, 8, 8, 32, 1)          0         ['tf.reshape[0][0]']
#
#  tf.concat (TFOpLambda)      (None, 8, 8, 32, 256)        0         ['leaky_re_lu_14[0][0]',
#                                                                      'tf.tile[0][0]']
#
#  fullscale_5_4 (UpSampling3  (None, 16, 16, 32, 256)      0         ['tf.concat[0][0]']
#  D)
#
#  fullscale_maxpool_3_4 (Max  (None, 16, 16, 32, 64)       0         ['leaky_re_lu_8[0][0]']
#  Pooling3D)
#
#  fullscale_maxpool_2_4 (Max  (None, 16, 16, 32, 32)       0         ['leaky_re_lu_5[0][0]']
#  Pooling3D)
#
#  fullscale_maxpool_1_4 (Max  (None, 16, 16, 32, 16)       0         ['leaky_re_lu_2[0][0]']
#  Pooling3D)
#
#  conv3d_15 (Conv3D)          (None, 16, 16, 32, 16)       110608    ['fullscale_5_4[0][0]']
#
#  conv3d_16 (Conv3D)          (None, 16, 16, 32, 16)       55312     ['leaky_re_lu_11[0][0]']
#
#  conv3d_17 (Conv3D)          (None, 16, 16, 32, 16)       27664     ['fullscale_maxpool_3_4[0][0]'
#                                                                     ]
#
#  conv3d_18 (Conv3D)          (None, 16, 16, 32, 16)       13840     ['fullscale_maxpool_2_4[0][0]'
#                                                                     ]
#
#  conv3d_19 (Conv3D)          (None, 16, 16, 32, 16)       6928      ['fullscale_maxpool_1_4[0][0]'
#                                                                     ]
#
#  batch_normalization_15 (Ba  (None, 16, 16, 32, 16)       64        ['conv3d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 16, 16, 32, 16)       64        ['conv3d_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 16, 16, 32, 16)       64        ['conv3d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 16, 16, 32, 16)       64        ['conv3d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 16, 16, 32, 16)       64        ['conv3d_19[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 16, 16, 32, 16)       0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 16, 16, 32, 16)       0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 16, 16, 32, 16)       0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 16, 16, 32, 16)       0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 16, 16, 32, 16)       0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  concatenate (Concatenate)   (None, 16, 16, 32, 80)       0         ['leaky_re_lu_15[0][0]',
#                                                                      'leaky_re_lu_16[0][0]',
#                                                                      'leaky_re_lu_17[0][0]',
#                                                                      'leaky_re_lu_18[0][0]',
#                                                                      'leaky_re_lu_19[0][0]']
#
#  conv3d_20 (Conv3D)          (None, 16, 16, 32, 80)       172880    ['concatenate[0][0]']
#
#  batch_normalization_20 (Ba  (None, 16, 16, 32, 80)       320       ['conv3d_20[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 16, 16, 32, 80)       0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  fullscale_5_3 (UpSampling3  (None, 32, 32, 32, 256)      0         ['tf.concat[0][0]']
#  D)
#
#  fullscale_4_3 (UpSampling3  (None, 32, 32, 32, 80)       0         ['leaky_re_lu_20[0][0]']
#  D)
#
#  fullscale_maxpool_2_3 (Max  (None, 32, 32, 32, 32)       0         ['leaky_re_lu_5[0][0]']
#  Pooling3D)
#
#  fullscale_maxpool_1_3 (Max  (None, 32, 32, 32, 16)       0         ['leaky_re_lu_2[0][0]']
#  Pooling3D)
#
#  conv3d_21 (Conv3D)          (None, 32, 32, 32, 16)       110608    ['fullscale_5_3[0][0]']
#
#  conv3d_22 (Conv3D)          (None, 32, 32, 32, 16)       34576     ['fullscale_4_3[0][0]']
#
#  conv3d_23 (Conv3D)          (None, 32, 32, 32, 16)       27664     ['leaky_re_lu_8[0][0]']
#
#  conv3d_24 (Conv3D)          (None, 32, 32, 32, 16)       13840     ['fullscale_maxpool_2_3[0][0]'
#                                                                     ]
#
#  conv3d_25 (Conv3D)          (None, 32, 32, 32, 16)       6928      ['fullscale_maxpool_1_3[0][0]'
#                                                                     ]
#
#  batch_normalization_21 (Ba  (None, 32, 32, 32, 16)       64        ['conv3d_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 32, 32, 32, 16)       64        ['conv3d_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 32, 32, 32, 16)       64        ['conv3d_23[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 32, 32, 32, 16)       64        ['conv3d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 32, 32, 32, 16)       64        ['conv3d_25[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 32, 32, 32, 16)       0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 32, 32, 32, 16)       0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 32, 32, 32, 16)       0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 32, 32, 32, 16)       0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 32, 32, 32, 16)       0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  concatenate_1 (Concatenate  (None, 32, 32, 32, 80)       0         ['leaky_re_lu_21[0][0]',
#  )                                                                   'leaky_re_lu_22[0][0]',
#                                                                      'leaky_re_lu_23[0][0]',
#                                                                      'leaky_re_lu_24[0][0]',
#                                                                      'leaky_re_lu_25[0][0]']
#
#  conv3d_26 (Conv3D)          (None, 32, 32, 32, 80)       172880    ['concatenate_1[0][0]']
#
#  batch_normalization_26 (Ba  (None, 32, 32, 32, 80)       320       ['conv3d_26[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 32, 32, 32, 80)       0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  fullscale_5_2 (UpSampling3  (None, 64, 64, 32, 256)      0         ['tf.concat[0][0]']
#  D)
#
#  fullscale_4_2 (UpSampling3  (None, 64, 64, 32, 80)       0         ['leaky_re_lu_20[0][0]']
#  D)
#
#  fullscale_3_2 (UpSampling3  (None, 64, 64, 32, 80)       0         ['leaky_re_lu_26[0][0]']
#  D)
#
#  fullscale_maxpool_1_2 (Max  (None, 64, 64, 32, 16)       0         ['leaky_re_lu_2[0][0]']
#  Pooling3D)
#
#  conv3d_27 (Conv3D)          (None, 64, 64, 32, 16)       110608    ['fullscale_5_2[0][0]']
#
#  conv3d_28 (Conv3D)          (None, 64, 64, 32, 16)       34576     ['fullscale_4_2[0][0]']
#
#  conv3d_29 (Conv3D)          (None, 64, 64, 32, 16)       34576     ['fullscale_3_2[0][0]']
#
#  conv3d_30 (Conv3D)          (None, 64, 64, 32, 16)       13840     ['leaky_re_lu_5[0][0]']
#
#  conv3d_31 (Conv3D)          (None, 64, 64, 32, 16)       6928      ['fullscale_maxpool_1_2[0][0]'
#                                                                     ]
#
#  batch_normalization_27 (Ba  (None, 64, 64, 32, 16)       64        ['conv3d_27[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 64, 64, 32, 16)       64        ['conv3d_28[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 64, 64, 32, 16)       64        ['conv3d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_30 (Ba  (None, 64, 64, 32, 16)       64        ['conv3d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 64, 64, 32, 16)       64        ['conv3d_31[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 64, 64, 32, 16)       0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 64, 64, 32, 16)       0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 64, 64, 32, 16)       0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 64, 64, 32, 16)       0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 64, 64, 32, 16)       0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  concatenate_2 (Concatenate  (None, 64, 64, 32, 80)       0         ['leaky_re_lu_27[0][0]',
#  )                                                                   'leaky_re_lu_28[0][0]',
#                                                                      'leaky_re_lu_29[0][0]',
#                                                                      'leaky_re_lu_30[0][0]',
#                                                                      'leaky_re_lu_31[0][0]']
#
#  conv3d_32 (Conv3D)          (None, 64, 64, 32, 80)       172880    ['concatenate_2[0][0]']
#
#  batch_normalization_32 (Ba  (None, 64, 64, 32, 80)       320       ['conv3d_32[0][0]']
#  tchNormalization)
#
#  spatial_dropout3d (Spatial  (None, 8, 8, 32, 256)        0         ['tf.concat[0][0]']
#  Dropout3D)
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 64, 64, 32, 80)       0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  CGM_conv (Conv3D)           (None, 8, 8, 32, 6)          1542      ['spatial_dropout3d[0][0]']
#
#  fullscale_5_1 (UpSampling3  (None, 128, 128, 32, 256)    0         ['tf.concat[0][0]']
#  D)
#
#  fullscale_4_1 (UpSampling3  (None, 128, 128, 32, 80)     0         ['leaky_re_lu_20[0][0]']
#  D)
#
#  fullscale_3_1 (UpSampling3  (None, 128, 128, 32, 80)     0         ['leaky_re_lu_26[0][0]']
#  D)
#
#  fullscale_2_1 (UpSampling3  (None, 128, 128, 32, 80)     0         ['leaky_re_lu_32[0][0]']
#  D)
#
#  global_max_pooling3d (Glob  (None, 6)                    0         ['CGM_conv[0][0]']
#  alMaxPooling3D)
#
#  conv3d_33 (Conv3D)          (None, 128, 128, 32, 16)     110608    ['fullscale_5_1[0][0]']
#
#  conv3d_34 (Conv3D)          (None, 128, 128, 32, 16)     34576     ['fullscale_4_1[0][0]']
#
#  conv3d_35 (Conv3D)          (None, 128, 128, 32, 16)     34576     ['fullscale_3_1[0][0]']
#
#  conv3d_36 (Conv3D)          (None, 128, 128, 32, 16)     34576     ['fullscale_2_1[0][0]']
#
#  conv3d_37 (Conv3D)          (None, 128, 128, 32, 16)     6928      ['leaky_re_lu_2[0][0]']
#
#  tf.nn.softmax (TFOpLambda)  (None, 6)                    0         ['global_max_pooling3d[0][0]']
#
#  batch_normalization_33 (Ba  (None, 128, 128, 32, 16)     64        ['conv3d_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 128, 128, 32, 16)     64        ['conv3d_34[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 128, 128, 32, 16)     64        ['conv3d_35[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 128, 128, 32, 16)     64        ['conv3d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 128, 128, 32, 16)     64        ['conv3d_37[0][0]']
#  tchNormalization)
#
#  tf.compat.v1.gather (TFOpL  (None, 5)                    0         ['tf.nn.softmax[0][0]']
#  ambda)
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 128, 128, 32, 16)     0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  leaky_re_lu_34 (LeakyReLU)  (None, 128, 128, 32, 16)     0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  leaky_re_lu_35 (LeakyReLU)  (None, 128, 128, 32, 16)     0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  leaky_re_lu_36 (LeakyReLU)  (None, 128, 128, 32, 16)     0         ['batch_normalization_36[0][0]
#                                                                     ']
#  leaky_re_lu_37 (LeakyReLU)  (None, 128, 128, 32, 16)     0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  tf.math.argmax (TFOpLambda  (None,)                      0         ['tf.compat.v1.gather[0][0]']
#  )
#
#  concatenate_3 (Concatenate  (None, 128, 128, 32, 80)     0         ['leaky_re_lu_33[0][0]',
#  )                                                                   'leaky_re_lu_34[0][0]',
#                                                                      'leaky_re_lu_35[0][0]',
#                                                                      'leaky_re_lu_36[0][0]',
#                                                                      'leaky_re_lu_37[0][0]']
#
#  tf.one_hot (TFOpLambda)     (None, 5)                    0         ['tf.math.argmax[0][0]']
#
#  conv3d_38 (Conv3D)          (None, 128, 128, 32, 80)     172880    ['concatenate_3[0][0]']
#
#  tf.ones_like (TFOpLambda)   (None, 5)                    0         ['tf.one_hot[0][0]']
#
#  batch_normalization_38 (Ba  (None, 128, 128, 32, 80)     320       ['conv3d_38[0][0]']
#  tchNormalization)
#
#  deepsup_conv_5 (Conv3D)     (None, 8, 8, 32, 6)          41478     ['tf.concat[0][0]']
#
#  tf.__operators__.getitem (  (None, 1)                    0         ['tf.ones_like[0][0]']
#  SlicingOpLambda)
#
#  deepsup_conv_4 (Conv3D)     (None, 16, 16, 32, 6)        12966     ['leaky_re_lu_20[0][0]']
#
#  deepsup_conv_3 (Conv3D)     (None, 32, 32, 32, 6)        12966     ['leaky_re_lu_26[0][0]']
#
#  deepsup_conv_2 (Conv3D)     (None, 64, 64, 32, 6)        12966     ['leaky_re_lu_32[0][0]']
#
#  leaky_re_lu_38 (LeakyReLU)  (None, 128, 128, 32, 80)     0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  deepsup_upsamp_5 (UpSampli  (None, 128, 128, 32, 6)      0         ['deepsup_conv_5[0][0]']
#  ng3D)
#
#  tf.concat_1 (TFOpLambda)    (None, 6)                    0         ['tf.__operators__.getitem[0][
#                                                                     0]',
#                                                                      'tf.one_hot[0][0]']
#
#  deepsup_upsamp_4 (UpSampli  (None, 128, 128, 32, 6)      0         ['deepsup_conv_4[0][0]']
#  ng3D)
#
#  deepsup_upsamp_3 (UpSampli  (None, 128, 128, 32, 6)      0         ['deepsup_conv_3[0][0]']
#  ng3D)
#
#  deepsup_upsamp_2 (UpSampli  (None, 128, 128, 32, 6)      0         ['deepsup_conv_2[0][0]']
#  ng3D)
#
#  deepsup_conv_1 (Conv3D)     (None, 128, 128, 32, 6)      12966     ['leaky_re_lu_38[0][0]']
#
#  output5 (Activation)        (None, 128, 128, 32, 6)      0         ['deepsup_upsamp_5[0][0]']
#
#  tf.reshape_1 (TFOpLambda)   (None, 1, 1, 1, 6)           0         ['tf.concat_1[0][0]']
#
#  output4 (Activation)        (None, 128, 128, 32, 6)      0         ['deepsup_upsamp_4[0][0]']
#
#  output3 (Activation)        (None, 128, 128, 32, 6)      0         ['deepsup_upsamp_3[0][0]']
#
#  output2 (Activation)        (None, 128, 128, 32, 6)      0         ['deepsup_upsamp_2[0][0]']
#
#  output1 (Activation)        (None, 128, 128, 32, 6)      0         ['deepsup_conv_1[0][0]']
#
#  cgm_input (InputLayer)      [(None, 6)]                  0         []
#
#  mask_input (InputLayer)     [(None, 128, 128, 32, 6)]    0         []
#
#  tf.math.multiply (TFOpLamb  (None, 128, 128, 32, 6)      0         ['output5[0][0]',
#  da)                                                                 'tf.reshape_1[0][0]']
# ...
#                                                                      'tf.__operators__.add_137[0][
#                                                                     0]']
#
#  tf.__operators__.add_139 (  ()                           0         ['tf.math.reduce_sum_81[0][0]'
#  TFOpLambda)                                                        ]
#
#  tf.__operators__.add_142 (  ()                           0         ['tf.__operators__.add_141[0][
#  TFOpLambda)                                                        0]']
#
#  tf.__operators__.add_146 (  ()                           0         ['tf.__operators__.add_145[0][
#  TFOpLambda)                                                        0]',
#                                                                      'tf.math.multiply_149[0][0]']
#
#  tf.__operators__.add_150 (  ()                           0         ['tf.math.reduce_sum_87[0][0]'
#  TFOpLambda)                                                        , 'tf.math.multiply_153[0][0]'
#                                                                     ]
#
#  tf.math.multiply_154 (TFOp  ()                           0         ['tf.math.reduce_sum_89[0][0]'
#  Lambda)                                                            ]
#
#  tf.__operators__.add_128 (  ()                           0         ['tf.math.pow_24[0][0]']
#  TFOpLambda)
#
#  tf.math.pow_25 (TFOpLambda  ()                           0         ['tf.math.subtract_77[0][0]']
#  )
#
#  tf.math.subtract_80 (TFOpL  ()                           0         ['tf.math.truediv_30[0][0]']
#  ambda)
#
#  tf.math.truediv_31 (TFOpLa  ()                           0         ['tf.__operators__.add_139[0][
#  mbda)                                                              0]',
#                                                                      'tf.__operators__.add_142[0][
#                                                                     0]']
#
#  tf.__operators__.add_144 (  ()                           0         ['tf.math.reduce_sum_84[0][0]'
#  TFOpLambda)                                                        ]
#
#  tf.__operators__.add_147 (  ()                           0         ['tf.__operators__.add_146[0][
#  TFOpLambda)                                                        0]']
#
#  tf.__operators__.add_151 (  ()                           0         ['tf.__operators__.add_150[0][
#  TFOpLambda)                                                        0]',
#                                                                      'tf.math.multiply_154[0][0]']
#
#  tf.__operators__.add_133 (  ()                           0         ['tf.__operators__.add_128[0][
#  TFOpLambda)                                                        0]',
#                                                                      'tf.math.pow_25[0][0]']
#
#  tf.math.pow_26 (TFOpLambda  ()                           0         ['tf.math.subtract_80[0][0]']
#  )
#
#  tf.math.subtract_83 (TFOpL  ()                           0         ['tf.math.truediv_31[0][0]']
#  ambda)
#
#  tf.math.truediv_32 (TFOpLa  ()                           0         ['tf.__operators__.add_144[0][
#  mbda)                                                              0]',
#                                                                      'tf.__operators__.add_147[0][
#                                                                     0]']
#
#  tf.__operators__.add_149 (  ()                           0         ['tf.math.reduce_sum_87[0][0]'
#  TFOpLambda)                                                        ]
#
#  tf.__operators__.add_152 (  ()                           0         ['tf.__operators__.add_151[0][
#  TFOpLambda)                                                        0]']
#
#  tf.__operators__.add_138 (  ()                           0         ['tf.__operators__.add_133[0][
#  TFOpLambda)                                                        0]',
#                                                                      'tf.math.pow_26[0][0]']
#
#  tf.math.pow_27 (TFOpLambda  ()                           0         ['tf.math.subtract_83[0][0]']
#  )
#
#  tf.math.subtract_86 (TFOpL  ()                           0         ['tf.math.truediv_32[0][0]']
#  ambda)
#
#  tf.math.truediv_33 (TFOpLa  ()                           0         ['tf.__operators__.add_149[0][
#  mbda)                                                              0]',
#                                                                      'tf.__operators__.add_152[0][
#                                                                     0]']
#
#  tf.__operators__.add_143 (  ()                           0         ['tf.__operators__.add_138[0][
#  TFOpLambda)                                                        0]',
#                                                                      'tf.math.pow_27[0][0]']
#
#  tf.math.pow_28 (TFOpLambda  ()                           0         ['tf.math.subtract_86[0][0]']
#  )
#
#  tf.math.subtract_89 (TFOpL  ()                           0         ['tf.math.truediv_33[0][0]']
#  ambda)
#
#  tf.__operators__.add_148 (  ()                           0         ['tf.__operators__.add_143[0][
#  TFOpLambda)                                                        0]',
#                                                                      'tf.math.pow_28[0][0]']
#
#  tf.math.pow_29 (TFOpLambda  ()                           0         ['tf.math.subtract_89[0][0]']
#  )
#
#  tf.__operators__.add_153 (  ()                           0         ['tf.__operators__.add_148[0][
#  TFOpLambda)                                                        0]',
#                                                                      'tf.math.pow_29[0][0]']
#
#  tf.math.truediv_34 (TFOpLa  ()                           0         ['tf.__operators__.add_153[0][
#  mbda)                                                              0]']
#
#  add_metric_4 (AddMetric)    ()                           0         ['tf.math.truediv_34[0][0]']
#
#  tf.clip_by_value_5 (TFOpLa  (None, 6)                    0         ['tf.nn.softmax[0][0]']
#  mbda)
#
#  tf.math.log (TFOpLambda)    (None, 6)                    0         ['tf.clip_by_value_5[0][0]']
#
#  tf.math.multiply_155 (TFOp  (None, 6)                    0         ['cgm_input[0][0]',
#  Lambda)                                                             'tf.math.log[0][0]']
#
#  tf.math.reduce_sum_90 (TFO  (None,)                      0         ['tf.math.multiply_155[0][0]']
#  pLambda)
#
#  tf.math.negative (TFOpLamb  (None,)                      0         ['tf.math.reduce_sum_90[0][0]'
#  da)                                                                ]
#
#  tf.math.reduce_mean (TFOpL  ()                           0         ['tf.math.negative[0][0]']
#  ambda)
#
#  add_metric_5 (AddMetric)    ()                           0         ['tf.math.reduce_mean[0][0]']
#
#  tf.math.multiply_156 (TFOp  ()                           0         ['tf.math.reduce_mean[0][0]']
#  Lambda)
#
#  add_loss (AddLoss)          ()                           0         ['tf.math.multiply_156[0][0]']
#
#  tf.__operators__.add_30 (T  ()                           0         ['tf.math.truediv_6[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_61 (T  ()                           0         ['tf.__operators__.add_30[0][0
#  FOpLambda)                                                         ]',
#                                                                      'tf.math.truediv_13[0][0]']
#
#  tf.__operators__.add_92 (T  ()                           0         ['tf.__operators__.add_61[0][0
#  FOpLambda)                                                         ]',
#                                                                      'tf.math.truediv_20[0][0]']
#
#  tf.__operators__.add_123 (  ()                           0         ['tf.__operators__.add_92[0][0
#  TFOpLambda)                                                        ]',
#                                                                      'tf.math.truediv_27[0][0]']
#
#  tf.__operators__.add_154 (  ()                           0         ['tf.__operators__.add_123[0][
#  TFOpLambda)                                                        0]',
#                                                                      'tf.math.truediv_34[0][0]']
#
#  add_loss_1 (AddLoss)        ()                           0         ['tf.__operators__.add_154[0][
#                                                                     0]']
#
#  tf.math.multiply_157 (TFOp  ()                           0         ['tf.__operators__.add_154[0][
#  Lambda)                                                            0]',
#                                                                      'tf.math.reduce_mean[0][0]']
#
#  add_metric_6 (AddMetric)    ()                           0         ['tf.math.multiply_157[0][0]']
#
# ==================================================================================================
# Total params: 7486187 (28.56 MB)
# Trainable params: 7481937 (28.54 MB)
# Non-trainable params: 4250 (16.60 KB)
# __________________________________________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
mc = ModelCheckpoint(f'models/{model_name}.h5',
                  save_best_only= True,
                    monitor='val_output1_loss',
                    mode='min')
model.fit(train_ds,
          validation_data = val_ds, 
          epochs=400-324,
          callbacks=[mc])
# Out:
# Epoch 1/76
# 116/116 [==============================] - 504s 4s/step - loss: 2.0840 - output5_loss: 0.6517 - output4_loss: 0.4813 - output3_loss: 0.3571 - output2_loss: 0.2985 - output1_loss: 0.2711 - cgm_loss: 0.0977 - cgm_focal_loss: 0.2245 - val_loss: 1.8589 - val_output5_loss: 0.6502 - val_output4_loss: 0.4488 - val_output3_loss: 0.3036 - val_output2_loss: 0.2257 - val_output1_loss: 0.1909 - val_cgm_loss: 0.1587 - val_cgm_focal_loss: 0.3370
# Epoch 2/76
# 116/116 [==============================] - 499s 4s/step - loss: 2.0874 - output5_loss: 0.6480 - output4_loss: 0.4783 - output3_loss: 0.3581 - output2_loss: 0.3004 - output1_loss: 0.2732 - cgm_loss: 0.1175 - cgm_focal_loss: 0.2747 - val_loss: 1.8607 - val_output5_loss: 0.6520 - val_output4_loss: 0.4517 - val_output3_loss: 0.2980 - val_output2_loss: 0.2308 - val_output1_loss: 0.1937 - val_cgm_loss: 0.1379 - val_cgm_focal_loss: 0.2930
# Epoch 3/76
#   3/116 [..............................] - ETA: 8:48 - loss: 2.0506 - output5_loss: 0.6948 - output4_loss: 0.4864 - output3_loss: 0.3556 - output2_loss: 0.2751 - output1_loss: 0.2375 - cgm_loss: 0.0050 - cgm_focal_loss: 0.0106
